# %% [markdown]
# # Importing the Python Liabraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the Dataset

# %%
df = pd.read_csv("cars.csv")

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# ## Display first five observation

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %% [markdown]
# ## Display last five observation

# %%
df.tail()
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
# ...

# %% [markdown]
# ## Display any random one sample data

# %%
df.sample()
# Out:
#          Make   Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 11754  Nissan  Xterra  2014  regular unleaded      261.0               6.0
#
#       Transmission Type     Driven_Wheels  Number of Doors Market Category  \
# 11754         AUTOMATIC  four wheel drive              4.0             NaN
#
#       Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 11754      Midsize       4dr SUV           20        15        2009  25440

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %% [markdown]
# # Observation

# %% [markdown]
# Data has only float, object and integer values.

# %% [markdown]
# Five columns have null/missing values.

# %% [markdown]
# ## Display the Variable names and their Data types

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %% [markdown]
# ## check how many columns have not null values

# %%
df.isnull()
# Out:
#         Make  Model   Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0      False  False  False             False      False             False
# 1      False  False  False             False      False             False
# 2      False  False  False             False      False             False
# 3      False  False  False             False      False             False
# 4      False  False  False             False      False             False
# ...      ...    ...    ...               ...        ...               ...
# 11909  False  False  False             False      False             False
# 11910  False  False  False             False      False             False
# 11911  False  False  False             False      False             False
# 11912  False  False  False             False      False             False
# 11913  False  False  False             False      False             False
#
#        Transmission Type  Driven_Wheels  Number of Doors  Market Category  \
# ...

# %% [markdown]
# ## Check how many null values have each column

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# Market Category      3742
# Engine HP              69
# Engine Cylinders       30
# Number of Doors         6
# Engine Fuel Type        3
# Make                    0
# Model                   0
# Year                    0
# Transmission Type       0
# Driven_Wheels           0
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
((df.isnull().sum()/len(df))*100).sort_values(ascending = True)
# Out:
# Make                  0.000000
# Model                 0.000000
# Year                  0.000000
# Transmission Type     0.000000
# Driven_Wheels         0.000000
# Vehicle Size          0.000000
# Vehicle Style         0.000000
# highway MPG           0.000000
# city mpg              0.000000
# Popularity            0.000000
# MSRP                  0.000000
# Engine Fuel Type      0.025180
# Number of Doors       0.050361
# Engine Cylinders      0.251805
# Engine HP             0.579151
# Market Category      31.408427
# dtype: float64

# %%
np.round(((df.isnull().sum()/len(df))*100).sort_values(ascending = False),2)
# Out:
# Market Category      31.41
# Engine HP             0.58
# Engine Cylinders      0.25
# Number of Doors       0.05
# Engine Fuel Type      0.03
# Make                  0.00
# Model                 0.00
# Year                  0.00
# Transmission Type     0.00
# Driven_Wheels         0.00
# Vehicle Size          0.00
# Vehicle Style         0.00
# highway MPG           0.00
# city mpg              0.00
# Popularity            0.00
# MSRP                  0.00
# dtype: float64

# %%
df.shape
# Out:
# (11914, 16)

# %% [markdown]
# ## Observation

# %% [markdown]
# There are 11914 Rows and 16 columns in this Dataset

# %% [markdown]
# # Engine HP

# %%
df[df['Engine HP'].isnull()]
# Out:
#          Make        Model  Year                Engine Fuel Type  Engine HP  \
# 539      FIAT         500e  2015                        electric        NaN
# 540      FIAT         500e  2016                        electric        NaN
# 541      FIAT         500e  2017                        electric        NaN
# 2905  Lincoln  Continental  2017  premium unleaded (recommended)        NaN
# 2906  Lincoln  Continental  2017  premium unleaded (recommended)        NaN
# ...       ...          ...   ...                             ...        ...
# 9850      Kia      Soul EV  2015                        electric        NaN
# 9851      Kia      Soul EV  2015                        electric        NaN
# 9852      Kia      Soul EV  2016                        electric        NaN
# 9853      Kia      Soul EV  2016                        electric        NaN
# 9854      Kia      Soul EV  2016                        electric        NaN
#
# ...

# %%
df['Engine HP']
# Out:
# 0        335.0
# 1        300.0
# 2        300.0
# 3        230.0
# 4        230.0
#          ...
# 11909    300.0
# 11910    300.0
# 11911    300.0
# 11912    300.0
# 11913    221.0
# Name: Engine HP, Length: 11914, dtype: float64

# %%
df.describe()['Engine HP']
# Out:
# count    11845.00000
# mean       249.38607
# std        109.19187
# min         55.00000
# 25%        170.00000
# 50%        227.00000
# 75%        300.00000
# max       1001.00000
# Name: Engine HP, dtype: float64

# %%
df['Engine HP'].fillna(int(df['Engine HP'].mean()), inplace = True)

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# ## Observation
# - There are 69 rows have null values.
# - mean is 249.38 and 50% percentile is 227.00000 which is nearest to mean means there is no outlier present in this column so we are impute values by mean.

# %% [markdown]
#  # Engine Cylinder

# %%
df[df['Engine Cylinders'].isnull()]
# Out:
#             Make    Model  Year             Engine Fuel Type  Engine HP  \
# 1983   Chevrolet  Bolt EV  2017                     electric      200.0
# 1984   Chevrolet  Bolt EV  2017                     electric      200.0
# 3716  Volkswagen   e-Golf  2015                     electric      115.0
# 3717  Volkswagen   e-Golf  2015                     electric      115.0
# 3718  Volkswagen   e-Golf  2016                     electric      115.0
# 3719  Volkswagen   e-Golf  2016                     electric      115.0
# 5778  Mitsubishi   i-MiEV  2014                     electric      249.0
# 5779  Mitsubishi   i-MiEV  2016                     electric       66.0
# 5780  Mitsubishi   i-MiEV  2017                     electric       66.0
# 8373      Toyota  RAV4 EV  2012                     electric      154.0
# 8695       Mazda     RX-7  1993             regular unleaded      255.0
# 8696       Mazda     RX-7  1994             regular unleaded      255.0
# ...

# %%
df.describe()['Engine Cylinders']
# Out:
# count    11884.000000
# mean         5.628829
# std          1.780559
# min          0.000000
# 25%          4.000000
# 50%          6.000000
# 75%          6.000000
# max         16.000000
# Name: Engine Cylinders, dtype: float64

# %%
df['Engine Cylinders'] = df['Engine Cylinders'].fillna(df['Engine Cylinders'].mean())

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# ## Observation
# - There are 30 rows have null values.
# - mean is 5.6 and 50% percentile is 6.0 which is nearest to mean means there is no outlier present in this column so we are impute values by mean.

# %% [markdown]
# # Engine Fuel Type

# %%
df['Engine Fuel Type'].isnull().sum()
# Out:
# 3

# %%
df[df['Engine Fuel Type'].isnull()]
# Out:
#          Make   Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 11321  Suzuki  Verona  2004              NaN      155.0               6.0
# 11322  Suzuki  Verona  2004              NaN      155.0               6.0
# 11323  Suzuki  Verona  2004              NaN      155.0               6.0
#
#       Transmission Type      Driven_Wheels  Number of Doors Market Category  \
# 11321         AUTOMATIC  front wheel drive              4.0             NaN
# 11322         AUTOMATIC  front wheel drive              4.0             NaN
# 11323         AUTOMATIC  front wheel drive              4.0             NaN
#
#       Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 11321      Midsize         Sedan           25        17         481  17199
# 11322      Midsize         Sedan           25        17         481  20199
# 11323      Midsize         Sedan           25        17         481  18499

# %%
df['Engine Fuel Type'].isnull().sum()
# Out:
# 3

# %%
md = df['Engine Fuel Type'].mode() ### impute the values 
print(md)
# Out:
# 0    regular unleaded
# Name: Engine Fuel Type, dtype: object

# %%
print(md[0])
# Out:
# regular unleaded

# %%
df['Engine Fuel Type'] = df['Engine Fuel Type'].fillna(md[0])   ###categorical 
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df['Engine Fuel Type'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Observation
# - There are 3 rows have null values.
# - These Column is categorical that's why using Mode() for imputation

# %% [markdown]
# # Market Category

# %%
df['Market Category'].isnull().sum()
# Out:
# 3742

# %%
df[df['Market Category'].isnull()]
# Out:
#          Make     Model  Year                Engine Fuel Type  Engine HP  \
# 87     Nissan     200SX  1996                regular unleaded      115.0
# 88     Nissan     200SX  1996                regular unleaded      115.0
# 91     Nissan     200SX  1997                regular unleaded      115.0
# 92     Nissan     200SX  1997                regular unleaded      115.0
# 93     Nissan     200SX  1998                regular unleaded      115.0
# ...       ...       ...   ...                             ...        ...
# 11794  Subaru        XT  1991                regular unleaded      145.0
# 11809  Toyota  Yaris iA  2017                regular unleaded      106.0
# 11810  Toyota  Yaris iA  2017                regular unleaded      106.0
# 11867     GMC     Yukon  2015  premium unleaded (recommended)      420.0
# 11868     GMC     Yukon  2015  premium unleaded (recommended)      420.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# ...

# %%
df.describe()
# Out:
#                Year     Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11914.000000      11914.000000     11908.000000
# mean    2010.384338    249.383834          5.628829         3.436093
# std        7.579740    108.875196          1.778316         0.881315
# min     1990.000000     55.000000          0.000000         2.000000
# 25%     2007.000000    170.000000          4.000000         2.000000
# 50%     2015.000000    227.000000          6.000000         4.000000
# 75%     2016.000000    300.000000          6.000000         4.000000
# max     2017.000000   1001.000000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
df['Market Category'].mode()
# Out:
# 0    Crossover
# Name: Market Category, dtype: object

# %%
df['Market Category'].fillna(df['Market Category'].mode()[0], inplace = True)

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df['Market Category'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Observation
# - There are 3742 rows have null values.
# - These Column is categorical that's why using Mode() for imputation

# %% [markdown]
# # Number of Doors

# %%
df.describe()['Number of Doors']
# Out:
# count    11908.000000
# mean         3.436093
# std          0.881315
# min          2.000000
# 25%          2.000000
# 50%          4.000000
# 75%          4.000000
# max          4.000000
# Name: Number of Doors, dtype: float64

# %%
df['Number of Doors'] = df['Number of Doors'].fillna(df['Number of Doors'].mean())

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# ## Observation
#
# - mean is 3.4 and 50% percentile is 4.0 which is nearest to mean means there is no outlier present in this column so we are impute values by mean.

# %%
df.isnull().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine Fuel Type     0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      0
# Market Category      0
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %% [markdown]
# - In all null values impute some values by statastical methods Mean, Meadian or Mode and make all of them not null values.

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
df['Year'] = df['Year'].astype(float)
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                 float64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
df['highway MPG'] = df['highway MPG'].astype(float)
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                 float64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG          float64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
df['city mpg'] = df['city mpg'].astype(float)
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                 float64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG          float64
# city mpg             float64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
df['Popularity'] = df['Popularity'].astype(float)
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                 float64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG          float64
# city mpg             float64
# Popularity           float64
# MSRP                   int64
# dtype: object

# %%
df['MSRP'] = df['MSRP'].astype(float)
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                 float64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG          float64
# city mpg             float64
# Popularity           float64
# MSRP                 float64
# dtype: object

# %% [markdown]
# - Convert Object data types in float

# %% [markdown]
# # Capping Outliers

# %%
cap = np.percentile(df['Year'],99)
print(cap)
# Out:
# 2017.0

# %%
df['Year'] = df['Year'].apply(lambda x : x if x < 2017.0 else 2017.0 )

# %%
plt.boxplot(df['Year'])
plt.show()

# %%
cap = np.percentile(df['Engine HP'],99)
print(cap)
# Out:
# 620.0

# %%
df['Engine HP'] = df['Engine HP'].apply(lambda x : x if x < 620.0 else 620.0 )

# %%
plt.boxplot(df['Engine HP'])
plt.show()

# %%
cap = np.percentile(df['Engine Cylinders'],99)
print(cap)
# Out:
# 12.0

# %%
df['Engine Cylinders'] = df['Engine Cylinders'].apply(lambda x : x if x < 12.0 else 12.0 )

# %%
plt.boxplot(df['Engine Cylinders'])
plt.show()

# %%
cap = np.percentile(df['Number of Doors'],99)
print(cap)
# Out:
# 4.0

# %%
df['Number of Doors'] = df['Number of Doors'].apply(lambda x : x if x < 4.0 else 4.0 )

# %%
plt.boxplot(df['Number of Doors'])
plt.show()

# %%
cap = np.percentile(df['highway MPG'],99)
print(cap)
# Out:
# 46.0

# %%
df['highway MPG'] = df['highway MPG'].apply(lambda x : x if x < 46.0 else 46.0 )

# %%
plt.boxplot(df['highway MPG'])
plt.show()

# %%
cap = np.percentile(df['city mpg'],99)
print(cap)
# Out:
# 44.0

# %%
df['city mpg'] = df['city mpg'].apply(lambda x : x if x < 44.0 else 44.0 )

# %%
plt.boxplot(df['city mpg'])
plt.show()

# %%
cap = np.percentile(df['Popularity'],99)
print(cap)
# Out:
# 5657.0

# %%
df['Popularity'] = df['Popularity'].apply(lambda x : x if x < 5657.0 else 5657.0 )

# %%
plt.boxplot(df['Popularity'])
plt.show()

# %%
cap = np.percentile(df['MSRP'],99)
print(cap)
# Out:
# 284488.1200000005

# %%
df['MSRP'] = df['MSRP'].apply(lambda x : x if x < 284488.12 else 284488.12 )

# %%
plt.boxplot(df['MSRP'])
plt.show()

# %% [markdown]
# # Univariet

# %% [markdown]
# ## Boxplot

# %%
df.boxplot(column = ['Year'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.boxplot(column = ['Engine HP'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.boxplot(column = ['Engine Cylinders'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.boxplot(column = ['Number of Doors'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.boxplot(column = ['highway MPG'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.boxplot(column = ['city mpg'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.boxplot(column = ['Popularity'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.boxplot(column = ['MSRP'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Displot

# %%
df['Year'].describe()
sns.displot(df['Year'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['Engine HP'].describe()
sns.displot(df['Engine HP'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['Engine Cylinders'].describe()
sns.displot(df['Engine Cylinders'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['Number of Doors'].describe()
sns.displot(df['Number of Doors'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['highway MPG'].describe()
sns.displot(df['highway MPG'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['city mpg'].describe()
sns.displot(df['city mpg'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['Popularity'].describe()
sns.displot(df['Popularity'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['MSRP'].describe()
sns.displot(df['MSRP'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Numeric Columns
#
# Year
# Engine HP
# Engine Cylinders
# Number of Doors
# highway MPG
# city mpg
# Popularity
# MSRP
#
#
# ### Categorical Columns
#
#
# -Make
# -Model
# -Engine Fuel Type
# -Transmission Type
# -Driven_Wheels
# -Market Category
# -Vehicle Size
# -Vehicle Style

# %% [markdown]
# # Byvariet Analysis

# %% [markdown]
# ## Scatter Plot

# %%
plt.scatter(df.Year, df.MSRP)
plt.show()

# %%
plt.scatter(df.Year, df.MSRP, alpha = 0.2, s = 50, c = 'green')
plt.show()

# %% [markdown]
# ### Observation

# %% [markdown]
# - When years passes the MSRP of car also Incrases.

# %%
plt.scatter(df.Year, df.Popularity)
plt.show()

# %%
plt.scatter(df.Year, df.Popularity, alpha = 0.2, s = 50, c = 'red')
plt.show()

# %% [markdown]
# ## Joint Plot

# %% [markdown]
# - There is scatterplot and histogram both in one plot.

# %%
sns.jointplot(df.Year, df.MSRP)
plt.show()

# %% [markdown]
# ## Observation

# %% [markdown]
# - In the year 2015 people buy those cars which MSRP is between 50000 and 100000

# %%
sns.jointplot(df.Year, df.Popularity)
plt.show()

# %% [markdown]
# ## Side by Side BoxPlot

# %%
## one numeric and one category

sns.boxplot(data = df, x = 'Make', y = 'Year')
plt.show()

# %%
sns.boxplot(data = df, x = 'Vehicle Size', y = 'Year')
plt.show()

# %% [markdown]
# ## Observation

# %% [markdown]
# - Between 2005-2018 people bought maximum the compact cars.
# - Between 2008-2017 people bought maximum the compact cars.
# - Between 2007-2017 people bought maximum the compact cars.

# %%
sns.boxplot(data = df, x = 'Popularity', y = 'Engine Fuel Type')
plt.show()

# %% [markdown]
# ## Observation

# %% [markdown]
# - Mostly people prefer flex-fuel(unleaded/E85) Engine type.
# - Least people using flex-fuel(premium unleaded required/E85)

# %% [markdown]
# ## Pairplot

# %%
## all numeric columns
sns.pairplot(df[['Year', 'Engine HP', 'Engine Cylinders', 'Number of Doors', 'highway MPG', 'city mpg', 'Popularity', 'MSRP']])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## Observation

# %% [markdown]
# - Pairplot with same column gives Barplot
# - Pairplot with other columns gives Scatterplot

# %% [markdown]
# ## Barplot

# %%
## groupby
df = df.groupby(['Vehicle Size'])['Engine HP'].mean()
df
# Out:
# Vehicle Size
# Compact    204.403652
# Large      316.844076
# Midsize    254.430368
# Name: Engine HP, dtype: float64

# %%
plt.figure(figsize = (6,4))
df.plot.bar()
plt.xlabel('Vehicle Size')
plt.ylabel('Mean Engine HP')
plt.show()

# %%
##df = df.groupby(['Vehicle Size'])['Number of Doors'].mean()
df
# Out:
# Vehicle Size
# Compact    204.403652
# Large      316.844076
# Midsize    254.430368
# Name: Engine HP, dtype: float64

# %% [markdown]
# # Multivariate Analysis

# %%
##sns.scatterplot(df['Year'], df['MSRP'], hue = df['Number of Doors'])

# %%
##sns.barplot(df['Engine Fuel Type'], df['MSRP'], hue = df['Vehicle Size'])

# %% [markdown]
# # Heat Map

# %%
cor1 = df.corr()

# %%
sns.heatmap(corr, annot = True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [104], in <cell line: 1>()
# ----> 1 sns.heatmap(corr, annot = True)
#       2 plt.show()
#
# NameError: name 'corr' is not defined
