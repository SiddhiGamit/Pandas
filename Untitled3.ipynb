# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("cars.csv")

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 0                   6.0            MANUAL   rear wheel drive              2.0
# 1                   6.0            MANUAL   rear wheel drive              2.0
# 2                   6.0            MANUAL   rear wheel drive              2.0
# 3                   6.0            MANUAL   rear wheel drive              2.0
# 4                   6.0            MANUAL   rear wheel drive              2.0
# ...                 ...               ...                ...              ...
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                              Market Category Vehicle Size  Vehicle Style  \
# 0      Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 1                         Luxury,Performance      Compact    Convertible
# 2                    Luxury,High-Performance      Compact          Coupe
# 3                         Luxury,Performance      Compact          Coupe
# 4                                     Luxury      Compact    Convertible
# ...                                      ...          ...            ...
# 11909             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11910             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11911             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11912             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11913                                 Luxury      Midsize          Sedan
#
#        highway MPG  city mpg  Popularity   MSRP
# 0               26        19        3916  46135
# 1               28        19        3916  40650
# 2               28        20        3916  36350
# 3               28        18        3916  29450
# 4               28        18        3916  34500
# ...            ...       ...         ...    ...
# 11909           23        16         204  46120
# 11910           23        16         204  56670
# 11911           23        16         204  50620
# 11912           23        16         204  50920
# 11913           26        17          61  28995
#
# [11914 rows x 16 columns]

# %%
# !pip install pandas_profiling
# Out:
# Requirement already satisfied: pandas_profiling in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (3.2.0)
# Requirement already satisfied: requests>=2.24.0 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from pandas_profiling) (2.26.0)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from pandas_profiling) (0.11.2)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from pandas_profiling) (0.2.0)
# Requirement already satisfied: multimethod>=1.4 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from pandas_profiling) (1.8)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from pandas_profiling) (1.7.1)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from pandas_profiling) (4.62.3)
# Requirement already satisfied: htmlmin>=0.1.12 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from pandas_profiling) (0.1.12)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from pandas_profiling) (6.0)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from pandas_profiling) (1.20.3)
# Requirement already satisfied: joblib~=1.1.0 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from pandas_profiling) (1.1.0)
# Requirement already satisfied: markupsafe~=2.1.1 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from pandas_profiling) (2.1.1)
# Requirement already satisfied: missingno>=0.4.2 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from pandas_profiling) (0.5.1)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from pandas_profiling) (3.4.3)
# Requirement already satisfied: visions[type_image_path]==0.7.4 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from pandas_profiling) (0.7.4)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from pandas_profiling) (1.3.4)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from pandas_profiling) (1.9.1)
# Requirement already satisfied: phik>=0.11.1 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from pandas_profiling) (0.12.2)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from pandas_profiling) (2.11.3)
# Requirement already satisfied: networkx>=2.4 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (2.6.3)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (21.2.0)
# Requirement already satisfied: imagehash in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (4.2.1)
# Requirement already satisfied: Pillow in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (1.3.1)
# Requirement already satisfied: six in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from cycler>=0.10->matplotlib>=3.2.0->pandas_profiling) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas_profiling) (2021.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from pydantic>=1.8.1->pandas_profiling) (3.10.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from requests>=2.24.0->pandas_profiling) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from requests>=2.24.0->pandas_profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from requests>=2.24.0->pandas_profiling) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from requests>=2.24.0->pandas_profiling) (1.26.7)
# Requirement already satisfied: colorama in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from tqdm>=4.48.2->pandas_profiling) (0.4.4)
# Requirement already satisfied: PyWavelets in c:\users\siddh\anaconda3\siddhiiiii\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas_profiling) (1.1.1)

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file = 'output.html')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2156/3649838013.py in <module>
# ----> 1 from pandas_profiling import ProfileReport
#       2 prof = ProfileReport(df)
#       3 prof.to_file(output_file = 'output.html')
#
# ~\anaconda3\Siddhiiiii\lib\site-packages\pandas_profiling\__init__.py in <module>
#       4 """
#       5
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# ~\anaconda3\Siddhiiiii\lib\site-packages\pandas_profiling\controller\pandas_decorator.py in <module>
#       2 from pandas import DataFrame
#       3
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       5
#       6
#
# ~\anaconda3\Siddhiiiii\lib\site-packages\pandas_profiling\profile_report.py in <module>
#      25 from pandas_profiling.report.presentation.core import Root
#      26 from pandas_profiling.report.presentation.core.renderable import Renderable
# ---> 27 from pandas_profiling.report.presentation.flavours.html.templates import (
#      28     create_html_assets,
#      29 )
#
# ~\anaconda3\Siddhiiiii\lib\site-packages\pandas_profiling\report\presentation\flavours\html\__init__.py in <module>
# ----> 1 from pandas_profiling.report.presentation.flavours.html.alerts import HTMLAlerts
#       2 from pandas_profiling.report.presentation.flavours.html.collapse import HTMLCollapse
#       3 from pandas_profiling.report.presentation.flavours.html.container import HTMLContainer
#       4 from pandas_profiling.report.presentation.flavours.html.duplicate import HTMLDuplicate
#       5 from pandas_profiling.report.presentation.flavours.html.frequency_table import (
#
# ~\anaconda3\Siddhiiiii\lib\site-packages\pandas_profiling\report\presentation\flavours\html\alerts.py in <module>
#       1 from pandas_profiling.report.presentation.core.alerts import Alerts
# ----> 2 from pandas_profiling.report.presentation.flavours.html import templates
#       3
#       4
#       5 class HTMLAlerts(Alerts):
#
# ~\anaconda3\Siddhiiiii\lib\site-packages\pandas_profiling\report\presentation\flavours\html\templates.py in <module>
#       3 from pathlib import Path
#       4
# ----> 5 import jinja2
#       6
#       7 from pandas_profiling.config import Settings, Theme
#
# ~\anaconda3\Siddhiiiii\lib\site-packages\jinja2\__init__.py in <module>
#      10 from .bccache import FileSystemBytecodeCache
#      11 from .bccache import MemcachedBytecodeCache
# ---> 12 from .environment import Environment
#      13 from .environment import Template
#      14 from .exceptions import TemplateAssertionError
#
# ~\anaconda3\Siddhiiiii\lib\site-packages\jinja2\environment.py in <module>
#      23 from .compiler import CodeGenerator
#      24 from .compiler import generate
# ---> 25 from .defaults import BLOCK_END_STRING
#      26 from .defaults import BLOCK_START_STRING
#      27 from .defaults import COMMENT_END_STRING
#
# ~\anaconda3\Siddhiiiii\lib\site-packages\jinja2\defaults.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2 from ._compat import range_type
# ----> 3 from .filters import FILTERS as DEFAULT_FILTERS  # noqa: F401
#       4 from .tests import TESTS as DEFAULT_TESTS  # noqa: F401
#       5 from .utils import Cycler
#
# ~\anaconda3\Siddhiiiii\lib\site-packages\jinja2\filters.py in <module>
#      11 from markupsafe import escape
#      12 from markupsafe import Markup
# ---> 13 from markupsafe import soft_unicode
#      14
#      15 from ._compat import abc
#
# ImportError: cannot import name 'soft_unicode' from 'markupsafe' (C:\Users\siddh\anaconda3\Siddhiiiii\lib\site-packages\markupsafe\__init__.py)

# %%
from pandas_profiling.profile_report import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2156/1228782139.py in <module>
# ----> 1 from pandas_profiling.profile_report import ProfileReport
#
# ~\anaconda3\Siddhiiiii\lib\site-packages\pandas_profiling\__init__.py in <module>
#       4 """
#       5
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# ~\anaconda3\Siddhiiiii\lib\site-packages\pandas_profiling\controller\pandas_decorator.py in <module>
#       2 from pandas import DataFrame
#       3
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       5
#       6
#
# ~\anaconda3\Siddhiiiii\lib\site-packages\pandas_profiling\profile_report.py in <module>
#      25 from pandas_profiling.report.presentation.core import Root
#      26 from pandas_profiling.report.presentation.core.renderable import Renderable
# ---> 27 from pandas_profiling.report.presentation.flavours.html.templates import (
#      28     create_html_assets,
#      29 )
#
# ~\anaconda3\Siddhiiiii\lib\site-packages\pandas_profiling\report\presentation\flavours\html\__init__.py in <module>
# ----> 1 from pandas_profiling.report.presentation.flavours.html.alerts import HTMLAlerts
#       2 from pandas_profiling.report.presentation.flavours.html.collapse import HTMLCollapse
#       3 from pandas_profiling.report.presentation.flavours.html.container import HTMLContainer
#       4 from pandas_profiling.report.presentation.flavours.html.duplicate import HTMLDuplicate
#       5 from pandas_profiling.report.presentation.flavours.html.frequency_table import (
#
# ~\anaconda3\Siddhiiiii\lib\site-packages\pandas_profiling\report\presentation\flavours\html\alerts.py in <module>
#       1 from pandas_profiling.report.presentation.core.alerts import Alerts
# ----> 2 from pandas_profiling.report.presentation.flavours.html import templates
#       3
#       4
#       5 class HTMLAlerts(Alerts):
#
# ~\anaconda3\Siddhiiiii\lib\site-packages\pandas_profiling\report\presentation\flavours\html\templates.py in <module>
#       3 from pathlib import Path
#       4
# ----> 5 import jinja2
#       6
#       7 from pandas_profiling.config import Settings, Theme
#
# ~\anaconda3\Siddhiiiii\lib\site-packages\jinja2\__init__.py in <module>
#      10 from .bccache import FileSystemBytecodeCache
#      11 from .bccache import MemcachedBytecodeCache
# ---> 12 from .environment import Environment
#      13 from .environment import Template
#      14 from .exceptions import TemplateAssertionError
#
# ~\anaconda3\Siddhiiiii\lib\site-packages\jinja2\environment.py in <module>
#      23 from .compiler import CodeGenerator
#      24 from .compiler import generate
# ---> 25 from .defaults import BLOCK_END_STRING
#      26 from .defaults import BLOCK_START_STRING
#      27 from .defaults import COMMENT_END_STRING
#
# ~\anaconda3\Siddhiiiii\lib\site-packages\jinja2\defaults.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2 from ._compat import range_type
# ----> 3 from .filters import FILTERS as DEFAULT_FILTERS  # noqa: F401
#       4 from .tests import TESTS as DEFAULT_TESTS  # noqa: F401
#       5 from .utils import Cycler
#
# ~\anaconda3\Siddhiiiii\lib\site-packages\jinja2\filters.py in <module>
#      11 from markupsafe import escape
#      12 from markupsafe import Markup
# ---> 13 from markupsafe import soft_unicode
#      14
#      15 from ._compat import abc
#
# ImportError: cannot import name 'soft_unicode' from 'markupsafe' (C:\Users\siddh\anaconda3\Siddhiiiii\lib\site-packages\markupsafe\__init__.py)
